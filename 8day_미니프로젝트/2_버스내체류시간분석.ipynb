# %% [markdown]
# # <버스 내 체류시간 분석>

# %% [markdown]
# ### 기준일 및 시간대별 버스내 체류시간(분) 분석비교

# %% [markdown]
# ### 파일 불러오기

# %%
import pandas as pd

# %%
# # 파일
# for i in range(1,81,1):
#     file_path = './포항버스정보/trfcard({})/trfcard.csv'.format(i)
#     globals()['df{}'.format(i)] = pd.read_csv(file_path, encoding='utf-8-sig')

# %%
df_total=pd.DataFrame()
for i in range(1,81,1):
    file_path = './포항/trfcard({})/trfcard.csv'.format(i)
    df = pd.read_csv(file_path, encoding='utf-8-sig')
    df_total = pd.concat([df_total, df])
    
    #globals()['df{}'.format(i)] = pd.read_csv(file_path, encoding='utf-8-sig')

# %%
len(df_total)
# Out:
# 842608

# %%
df_total.head(1)
# Out:
#           on_date        off_date route_name           descr age_type  \
# 0  20200102051049  20200102051844        131  양덕-송도-시청-양학-양덕       일반
#
#   trans_yn addfee_yn start_bstop  start_gps_x  start_gps_y end_bstop  \
# 0        N         N       양덕차고지   129.401693    36.077258    동부초등학교
#
#     end_gps_x  end_gps_y
# 0  129.380866  36.062209

# %%
col_name = pd.read_excel('./포항/trfcard(1)/trfcard_columns.xlsx', header = 2)
col_name


kor_col = []
for j in range (len(col_name)):
    kor_col.append(col_name['컬럼명 (한글)'][j])
print(kor_col)


df_total.columns = kor_col
df_total
# Out:
# ['승차시각', '하차시각', '노선명', '노선설명', '승객연령', '환승여부', '추가운임여부', '승차정류장', '승차정류장 GPS X', '승차정류장 GPS Y', '하차정류장', '하차정류장 GPS X', '하차정류장 GPS Y']
#                 승차시각            하차시각  노선명                      노선설명 승객연령 환승여부  \
# 0     20200102051049  20200102051844  131            양덕-송도-시청-양학-양덕   일반    N
# 1     20200102051338  20200102054549  175          문덕-고속터미널-선린병원-달전   일반    N
# 2     20200102051549  20200102051930  160            문덕-대송-송도-죽도-용흥   일반    N
# 3     20200102051617  20200102055046  175          문덕-고속터미널-선린병원-달전   일반    N
# 4     20200102051841  20200102052310  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# ...              ...             ...  ...                       ...  ...  ...
# 3870  20200328232420  20200328232628  200           양덕-남구청(야구장)-구룡포   일반    N
# 3871  20200328232523  20200328233525  130  양덕-장량지구-양학-시청-송도-장량지구-양덕   일반    N
# 3872  20200328232554  20200328233435  160            문덕-대송-송도-죽도-용흥   일반    N
# 3873  20200328232722  20200328235259  107           문덕-시외(고속)터미널-흥해   일반    N
# 3874  20200328233455  20200328234805  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    Y
#
#      추가운임여부        승차정류장  승차정류장 GPS X  승차정류장 GPS Y      하차정류장  하차정류장 GPS X  \
# 0         N        양덕차고지   129.401693    36.077258     동부초등학교   129.380866
# 1         N        문덕사거리   129.403178    35.962298  새마을금고해도지점   129.370626
# 2         N        문덕사거리   129.403442    35.962846    성우오토모티브   129.384492
# 3         N       부영사랑3차   129.402520    35.973038        오거리   129.366312
# 4         N         문덕온천   129.406532    35.961964      용덕사거리   129.415174
# ...     ...          ...          ...          ...        ...          ...
# 3870      N        형산로터리   129.368470    36.011630  뱃머리 평생학습원   129.354538
# 3871      N        북구보건소   129.379384    36.070790      삼성쉐르빌   129.405302
# 3872      N          북구청   129.367128    36.041941     송림초등학교   129.375650
# 3873      N  KTX포항역(시내행)   129.342368    36.072374      SK뷰2차   129.340636
# 3874      N       청림초등학교   129.405768    35.992544      문덕사거리   129.402914
#
#       하차정류장 GPS Y
# 0       36.062209
# 1       36.015468
# 2       35.972675
# 3       36.031816
# 4       35.972826
# ...           ...
# 3870    36.009020
# 3871    36.086089
# 3872    36.029730
# 3873    36.008334
# 3874    35.962293
#
# [842608 rows x 13 columns]

# %% [markdown]
# # 데이터 확인

# %%
# 결측치 확인
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842608 entries, 0 to 3874
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   승차시각         842608 non-null  int64
#  1   하차시각         842608 non-null  int64
#  2   노선명          842608 non-null  object
#  3   노선설명         842608 non-null  object
#  4   승객연령         842608 non-null  object
#  5   환승여부         842608 non-null  object
#  6   추가운임여부       842608 non-null  object
#  7   승차정류장        842608 non-null  object
#  8   승차정류장 GPS X  842608 non-null  float64
#  9   승차정류장 GPS Y  842608 non-null  float64
#  10  하차정류장        842608 non-null  object
#  11  하차정류장 GPS X  842608 non-null  float64
#  12  하차정류장 GPS Y  842608 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 90.0+ MB

# %%
df_total.describe()
# Out:
#                승차시각          하차시각    승차정류장 GPS X    승차정류장 GPS Y  \
# count  8.426080e+05  8.426080e+05  842608.000000  842608.000000
# mean   2.020017e+13  2.020017e+13     129.369875      36.033987
# std    6.691819e+07  6.691830e+07       0.051007       0.044272
# min    2.020010e+13  2.020010e+13     129.025585      35.804119
# 25%    2.020012e+13  2.020012e+13     129.350290      36.010240
# 50%    2.020013e+13  2.020013e+13     129.365486      36.031170
# 75%    2.020022e+13  2.020022e+13     129.384770      36.064088
# max    2.020033e+13  2.020040e+13     129.579045      36.303479
#
#          하차정류장 GPS X    하차정류장 GPS Y
# count  842608.000000  842608.000000
# mean      129.369699      36.030874
# std         0.042348       0.034512
# min       129.025585      35.804119
# 25%       129.353856      36.013250
# 50%       129.365281      36.033732
# 75%       129.371682      36.045735
# max       129.579045      36.303479

# %% [markdown]
# # datetime

# %%
df_total = df_total.astype('str')

# %%
df_total['년(승차)'] = df_total['승차시각'].str[:4]
df_total['월(승차)'] = df_total['승차시각'].str[4:6]
df_total['일(승차)'] = df_total['승차시각'].str[6:8]
df_total['시(승차)'] = df_total['승차시각'].str[8:10]
df_total['분(승차)'] = df_total['승차시각'].str[10:12]
df_total['초(승차)'] = df_total['승차시각'].str[12:]

df_total['년(하차)'] = df_total['하차시각'].str[:4]
df_total['월(하차)'] = df_total['하차시각'].str[4:6]
df_total['일(하차)'] = df_total['하차시각'].str[6:8]
df_total['시(하차)'] = df_total['하차시각'].str[8:10]
df_total['분(하차)'] = df_total['하차시각'].str[10:12]
df_total['초(하차)'] = df_total['하차시각'].str[12:]

# %%
df_total
# Out:
#                 승차시각            하차시각  노선명                      노선설명 승객연령 환승여부  \
# 0     20200102051049  20200102051844  131            양덕-송도-시청-양학-양덕   일반    N
# 1     20200102051338  20200102054549  175          문덕-고속터미널-선린병원-달전   일반    N
# 2     20200102051549  20200102051930  160            문덕-대송-송도-죽도-용흥   일반    N
# 3     20200102051617  20200102055046  175          문덕-고속터미널-선린병원-달전   일반    N
# 4     20200102051841  20200102052310  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# ...              ...             ...  ...                       ...  ...  ...
# 3870  20200328232420  20200328232628  200           양덕-남구청(야구장)-구룡포   일반    N
# 3871  20200328232523  20200328233525  130  양덕-장량지구-양학-시청-송도-장량지구-양덕   일반    N
# 3872  20200328232554  20200328233435  160            문덕-대송-송도-죽도-용흥   일반    N
# 3873  20200328232722  20200328235259  107           문덕-시외(고속)터미널-흥해   일반    N
# 3874  20200328233455  20200328234805  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    Y
#
#      추가운임여부        승차정류장 승차정류장 GPS X 승차정류장 GPS Y  ... 일(승차) 시(승차) 분(승차) 초(승차)  \
# 0         N        양덕차고지  129.401693   36.077258  ...    02    05    10    49
# 1         N        문덕사거리  129.403178   35.962298  ...    02    05    13    38
# 2         N        문덕사거리  129.403442   35.962846  ...    02    05    15    49
# 3         N       부영사랑3차   129.40252   35.973038  ...    02    05    16    17
# 4         N         문덕온천  129.406532   35.961964  ...    02    05    18    41
# ...     ...          ...         ...         ...  ...   ...   ...   ...   ...
# 3870      N        형산로터리   129.36847    36.01163  ...    28    23    24    20
# 3871      N        북구보건소  129.379384    36.07079  ...    28    23    25    23
# 3872      N          북구청  129.367128   36.041941  ...    28    23    25    54
# 3873      N  KTX포항역(시내행)  129.342368   36.072374  ...    28    23    27    22
# 3874      N       청림초등학교  129.405768   35.992544  ...    28    23    34    55
#
#      년(하차) 월(하차) 일(하차) 시(하차) 분(하차) 초(하차)
# 0     2020    01    02    05    18    44
# 1     2020    01    02    05    45    49
# 2     2020    01    02    05    19    30
# 3     2020    01    02    05    50    46
# 4     2020    01    02    05    23    10
# ...    ...   ...   ...   ...   ...   ...
# 3870  2020    03    28    23    26    28
# 3871  2020    03    28    23    35    25
# 3872  2020    03    28    23    34    35
# 3873  2020    03    28    23    52    59
# 3874  2020    03    28    23    48    05
#
# [842608 rows x 25 columns]

# %% [markdown]
# # 소요시간

# %%
# 소요시간
df_total['승차시각'] = df_total['승차시각'].astype(str)
df_total['하차시각'] = df_total['하차시각'].astype(str)

df_total['소요시간'] = pd.to_datetime(df_total['하차시각']) - pd.to_datetime(df_total['승차시각'])
df_total.head()
# Out:
#              승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0  20200102051049  20200102051844  131         양덕-송도-시청-양학-양덕   일반    N
# 1  20200102051338  20200102054549  175       문덕-고속터미널-선린병원-달전   일반    N
# 2  20200102051549  20200102051930  160         문덕-대송-송도-죽도-용흥   일반    N
# 3  20200102051617  20200102055046  175       문덕-고속터미널-선린병원-달전   일반    N
# 4  20200102051841  20200102052310  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
#
#   추가운임여부   승차정류장 승차정류장 GPS X 승차정류장 GPS Y  ... 시(승차) 분(승차) 초(승차) 년(하차) 월(하차)  \
# 0      N   양덕차고지  129.401693   36.077258  ...    05    10    49  2020    01
# 1      N   문덕사거리  129.403178   35.962298  ...    05    13    38  2020    01
# 2      N   문덕사거리  129.403442   35.962846  ...    05    15    49  2020    01
# 3      N  부영사랑3차   129.40252   35.973038  ...    05    16    17  2020    01
# 4      N    문덕온천  129.406532   35.961964  ...    05    18    41  2020    01
#
#   일(하차) 시(하차) 분(하차) 초(하차)            소요시간
# 0    02    05    18    44 0 days 00:07:55
# 1    02    05    45    49 0 days 00:32:11
# 2    02    05    19    30 0 days 00:03:41
# 3    02    05    50    46 0 days 00:34:29
# 4    02    05    23    10 0 days 00:04:29
#
# [5 rows x 26 columns]

# %% [markdown]
# # --

# %%
df_total = df_total.copy()
df_total.head(1)
# Out:
#              승차시각            하차시각  노선명            노선설명 승객연령 환승여부 추가운임여부  \
# 0  20200102051049  20200102051844  131  양덕-송도-시청-양학-양덕   일반    N      N
#
#    승차정류장 승차정류장 GPS X 승차정류장 GPS Y  ... 시(승차) 분(승차) 초(승차) 년(하차) 월(하차) 일(하차)  \
# 0  양덕차고지  129.401693   36.077258  ...    05    10    49  2020    01    02
#
#   시(하차) 분(하차) 초(하차)            소요시간
# 0    05    18    44 0 days 00:07:55
#
# [1 rows x 26 columns]

# %%
df_total['시(승차)'] = df_total['시(승차)'].astype(int)
df_total['분(승차)'] = df_total['분(승차)'].astype(int)
df_total['체류시간(분)'] = df_total['시(승차)'] * 60 + df_total['분(승차)']
df_total
# Out:
#                 승차시각            하차시각  노선명                      노선설명 승객연령 환승여부  \
# 0     20200102051049  20200102051844  131            양덕-송도-시청-양학-양덕   일반    N
# 1     20200102051338  20200102054549  175          문덕-고속터미널-선린병원-달전   일반    N
# 2     20200102051549  20200102051930  160            문덕-대송-송도-죽도-용흥   일반    N
# 3     20200102051617  20200102055046  175          문덕-고속터미널-선린병원-달전   일반    N
# 4     20200102051841  20200102052310  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# ...              ...             ...  ...                       ...  ...  ...
# 3870  20200328232420  20200328232628  200           양덕-남구청(야구장)-구룡포   일반    N
# 3871  20200328232523  20200328233525  130  양덕-장량지구-양학-시청-송도-장량지구-양덕   일반    N
# 3872  20200328232554  20200328233435  160            문덕-대송-송도-죽도-용흥   일반    N
# 3873  20200328232722  20200328235259  107           문덕-시외(고속)터미널-흥해   일반    N
# 3874  20200328233455  20200328234805  102     문덕-남구청-고속터미널-북구보건소-양덕   일반    Y
#
#      추가운임여부        승차정류장 승차정류장 GPS X 승차정류장 GPS Y  ... 분(승차) 초(승차) 년(하차) 월(하차)  \
# 0         N        양덕차고지  129.401693   36.077258  ...    10    49  2020    01
# 1         N        문덕사거리  129.403178   35.962298  ...    13    38  2020    01
# 2         N        문덕사거리  129.403442   35.962846  ...    15    49  2020    01
# 3         N       부영사랑3차   129.40252   35.973038  ...    16    17  2020    01
# 4         N         문덕온천  129.406532   35.961964  ...    18    41  2020    01
# ...     ...          ...         ...         ...  ...   ...   ...   ...   ...
# 3870      N        형산로터리   129.36847    36.01163  ...    24    20  2020    03
# 3871      N        북구보건소  129.379384    36.07079  ...    25    23  2020    03
# 3872      N          북구청  129.367128   36.041941  ...    25    54  2020    03
# 3873      N  KTX포항역(시내행)  129.342368   36.072374  ...    27    22  2020    03
# 3874      N       청림초등학교  129.405768   35.992544  ...    34    55  2020    03
#
#      일(하차) 시(하차)  분(하차)  초(하차)            소요시간 체류시간(분)
# 0       02    05     18     44 0 days 00:07:55     310
# 1       02    05     45     49 0 days 00:32:11     313
# 2       02    05     19     30 0 days 00:03:41     315
# 3       02    05     50     46 0 days 00:34:29     316
# 4       02    05     23     10 0 days 00:04:29     318
# ...    ...   ...    ...    ...             ...     ...
# 3870    28    23     26     28 0 days 00:02:08    1404
# 3871    28    23     35     25 0 days 00:10:02    1405
# 3872    28    23     34     35 0 days 00:08:41    1405
# 3873    28    23     52     59 0 days 00:25:37    1407
# 3874    28    23     48     05 0 days 00:13:10    1414
#
# [842608 rows x 27 columns]

# %%
df_total_pivot = df_total.pivot_table(values = '체류시간(분)',
                                      index = '일(승차)',
                                      columns = '시(승차)',
                                      aggfunc = 'sum')

# %%
df_total_pivot
# Out:
# 시(승차)   0        5         6         7          8          9          10  \
# 일(승차)
# 01     NaN  73749.0  240040.0  398478.0   723140.0   791485.0   959978.0
# 02     NaN  68432.0  268118.0  645865.0  1072970.0  1218065.0  1334641.0
# 03     NaN  96346.0  350438.0  901606.0  1340077.0  1493983.0  1684670.0
# 04     NaN  89154.0  356883.0  814809.0  1143966.0  1264301.0  1493027.0
# 05     NaN  82323.0  298341.0  650930.0   977968.0  1115801.0  1287945.0
# 06     NaN  92984.0  377347.0  934562.0  1363323.0  1490564.0  1528231.0
# 07     NaN  80398.0  323558.0  764784.0  1168925.0  1318183.0  1439908.0
# 08     NaN  72805.0  252495.0  605945.0   945188.0  1068103.0  1251452.0
# 09     NaN  80570.0  281661.0  697159.0  1039615.0  1230909.0  1363010.0
# 10     NaN  84372.0  329948.0  904210.0  1303377.0  1469943.0  1692035.0
# 11     NaN  86647.0  313943.0  821734.0  1202613.0  1405911.0  1643643.0
# 12     NaN  79803.0  294903.0  671447.0   990007.0  1094203.0  1298571.0
# 13     NaN  87349.0  356398.0  897673.0  1372258.0  1663687.0  1817482.0
# 14     NaN  65933.0  281638.0  724170.0  1134017.0  1276946.0  1408388.0
# 15     8.0  66527.0  216981.0  574695.0   933205.0  1136769.0  1292721.0
# 16     NaN  47633.0  187934.0  484768.0   767407.0   914461.0  1092053.0
# 17     NaN  61250.0  264772.0  691714.0  1113236.0  1289827.0  1365378.0
# 18     NaN  61017.0  204725.0  530965.0   857285.0   987740.0  1098371.0
# 19     NaN  56087.0  195411.0  488812.0   775986.0   830705.0   986598.0
# 20     NaN  66425.0  261285.0  691024.0  1081059.0  1256329.0  1425291.0
# 21     NaN  59654.0  252579.0  671616.0   994624.0  1121329.0  1216320.0
# 22     NaN  58151.0  205199.0  544896.0   797481.0   975365.0  1037658.0
# 23     NaN  45274.0  160577.0  396040.0   615282.0   745635.0   849167.0
# 24     NaN  55752.0  171072.0  397134.0   512718.0   629473.0   710354.0
# 25     NaN  24438.0  122006.0  237982.0   302488.0   338309.0   368757.0
# 26     NaN  42961.0  152750.0  304622.0   442085.0   487794.0   614919.0
# 27     NaN  53807.0  180032.0  373209.0   543553.0   591505.0   612094.0
# 28     NaN  68635.0  241769.0  532744.0   805135.0   900295.0   956236.0
# 29     NaN  50183.0  183288.0  493424.0   726282.0   854431.0   936594.0
# 30     NaN  28948.0  126136.0  365348.0   540962.0   661352.0   991211.0
# 31     NaN  41822.0  158052.0  389424.0   583346.0   659021.0   744099.0
#
# 시(승차)         11         12         13         14         15         16  \
# 일(승차)
# 01     1153699.0  1357199.0  1456058.0  1587174.0  1751359.0  1649585.0
# 02     1586310.0  1721025.0  1959259.0  2100081.0  2355888.0  2271577.0
# 03     1922495.0  2023254.0  2375676.0  2529410.0  2866004.0  2890534.0
# 04     1698653.0  1985039.0  2107521.0  2191044.0  2456184.0  2608537.0
# 05     1474957.0  1679562.0  1891455.0  2052457.0  2281943.0  2285739.0
# 06     1846446.0  1956066.0  2223271.0  2516231.0  2656843.0  2614892.0
# 07     1634715.0  1731075.0  1920160.0  2183333.0  2329836.0  2421483.0
# 08     1503806.0  1689453.0  1860695.0  2054332.0  2222610.0  2243482.0
# 09     1552589.0  1774522.0  1976563.0  2191599.0  2419913.0  2410813.0
# 10     2010690.0  2152798.0  2442001.0  2633598.0  2774535.0  2797671.0
# 11     1865795.0  2071195.0  2221440.0  2352896.0  2732919.0  2618262.0
# 12     1360702.0  1555779.0  1688968.0  1908111.0  2128463.0  2123674.0
# 13     2088386.0  2183869.0  2560171.0  2586700.0  2977030.0  2856177.0
# 14     1679850.0  1880901.0  2008244.0  2267466.0  2367407.0  2458692.0
# 15     1610040.0  1710985.0  1922612.0  1964606.0  2176129.0  2173529.0
# 16     1244537.0  1361762.0  1590539.0  1688127.0  1785686.0  1842424.0
# 17     1635593.0  1778422.0  1938013.0  2130852.0  2414540.0  2357838.0
# 18     1297538.0  1610610.0  1737408.0  1794705.0  1943452.0  1915048.0
# 19     1149367.0  1391622.0  1559307.0  1605934.0  1931675.0  1815533.0
# 20     1668719.0  1787112.0  1885402.0  2060190.0  2164512.0  2074616.0
# 21     1291672.0  1443852.0  1546675.0  1756471.0  1877971.0  1816396.0
# 22     1282347.0  1421393.0  1464594.0  1542278.0  1615769.0  1595805.0
# 23      999878.0  1163162.0  1379660.0  1404425.0  1572215.0  1534150.0
# 24      709249.0   792417.0   939795.0  1036312.0  1132576.0  1029495.0
# 25      455695.0   519709.0   588920.0   676003.0   754684.0   834534.0
# 26      670067.0   803433.0  1019828.0  1141093.0  1269622.0  1318414.0
# 27      741339.0   794777.0   869869.0  1153556.0  1188757.0  1190172.0
# 28     1063159.0  1299737.0  1473664.0  1583105.0  1909786.0  1865487.0
# 29     1064550.0  1250070.0  1418675.0  1455814.0  1498512.0  1458919.0
# 30     1129242.0  1194287.0  1279362.0  1485835.0  1746174.0  1766511.0
# 31      845920.0  1057763.0  1189030.0  1232160.0  1554814.0  1495456.0
#
# 시(승차)         17         18         19         20         21         22  \
# 일(승차)
# 01     1786680.0  1636338.0  1300764.0  1168001.0  1128127.0   834147.0
# 02     2350219.0  2089613.0  1403196.0  1332274.0  1299973.0  1024701.0
# 03     2857998.0  2659717.0  1618683.0  1388098.0  1405378.0  1078639.0
# 04     2635815.0  2211362.0  1430269.0  1334359.0  1307790.0   958064.0
# 05     2323691.0  2094441.0  1357275.0  1262746.0  1284532.0   879373.0
# 06     2619498.0  2290825.0  1416200.0  1270460.0  1160686.0   967549.0
# 07     2526710.0  2267853.0  1454971.0  1296053.0  1328667.0   975030.0
# 08     2348959.0  2150259.0  1383363.0  1318712.0  1321193.0   971439.0
# 09     2410099.0  2214155.0  1423199.0  1371599.0  1355867.0   890595.0
# 10     2837693.0  2749398.0  1704376.0  1403785.0  1435723.0  1077480.0
# 11     2758775.0  2421525.0  1493852.0  1351930.0  1352799.0  1007752.0
# 12     2330775.0  2113829.0  1399767.0  1180008.0  1244654.0   979942.0
# 13     2945451.0  2773461.0  1541906.0  1486675.0  1392792.0  1073686.0
# 14     2534259.0  2525326.0  1437354.0  1280118.0  1274483.0   971410.0
# 15     2316436.0  1975390.0  1253499.0  1182805.0  1155423.0   917185.0
# 16     1975561.0  1696907.0  1137306.0  1170453.0  1094181.0   821558.0
# 17     2293906.0  2133218.0  1238246.0  1147170.0  1182553.0   842098.0
# 18     1956442.0  1891631.0  1272973.0  1084941.0  1175962.0   839396.0
# 19     1878790.0  1689330.0  1143292.0  1017173.0  1041926.0   740306.0
# 20     2199188.0  1948738.0  1106810.0  1009533.0   966406.0   742364.0
# 21     1933096.0  1846919.0  1075559.0  1019862.0   936721.0   722451.0
# 22     1583456.0  1494667.0   875458.0   755573.0   812772.0   584058.0
# 23     1463450.0  1338032.0  1076175.0   823608.0   830437.0   686330.0
# 24     1021480.0   956532.0   684096.0   560109.0   483340.0   424238.0
# 25      767547.0   816148.0   624394.0   663637.0   518893.0   406407.0
# 26     1310543.0  1347089.0   832638.0   742289.0   679287.0   548078.0
# 27     1211734.0  1147313.0   735146.0   719439.0   632845.0   485589.0
# 28     1832387.0  1753194.0  1011681.0   945696.0   968871.0   662049.0
# 29     1402978.0  1370847.0   865336.0   846493.0   863160.0   561177.0
# 30     1808542.0  1672372.0   905198.0   852221.0   782203.0   608437.0
# 31     1541622.0  1359114.0   859737.0   759235.0   727832.0   565710.0
#
# 시(승차)        23
# 일(승차)
# 01     191215.0
# 02     210311.0
# 03     248130.0
# 04     218704.0
# 05     149247.0
# 06     203418.0
# 07     198218.0
# 08     211992.0
# 09     218888.0
# 10     259404.0
# 11     212038.0
# 12     200903.0
# 13     215875.0
# 14     203785.0
# 15     182485.0
# 16     166069.0
# 17     158984.0
# 18     200961.0
# 19     157433.0
# 20     167231.0
# 21     182748.0
# 22     129580.0
# 23     170446.0
# 24     108652.0
# 25     121356.0
# 26     142405.0
# 27     110127.0
# 28     146254.0
# 29     154707.0
# 30     102961.0
# 31     118528.0

# %% [markdown]
# # 시각화

# %% [markdown]
# ### 2-1 기준일 및 시간대별 버스내 체류시간(분) 분석비교

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(25,10))
plt.rc("font", family = "Malgun Gothic", size=10)
sns.heatmap(df_total_pivot, annot=True, fmt='.0f', cmap='rocket_r')
plt.title("-")
plt.show()

# %% [markdown]
# ### 시간 및 승객구분별 빈도분석 비교

# %%
df_total_fre=df_total.pivot_table(index = '승객연령',columns='시(승차)',values = '승차시각', aggfunc='count')
df_total_fre.fillna(0)

plt.rc('font', family = 'Malgun Gothic', size = 15)
plt.figure(figsize=(30,15))
sns.heatmap(df_total_fre, annot = True, fmt='.0f', cmap='rocket_r')
plt.title('시간 및 승객구분별 빈도분석 비교')
plt.show()
